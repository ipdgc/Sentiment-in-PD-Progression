# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# nltk.downloader.download('vader_lexicon')

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid', context='talk', palette='Dark2')

import string
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-99dd96a1eef1> in <module>
#       4 from nltk.corpus import stopwords
#       5 from PIL import Image
# ----> 6 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#       7 # nltk.downloader.download('vader_lexicon')
#       8
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
pip i

# %%
submissions_data = pd.read_csv("~/Dropbox/DZ_Work/UCL/RA_PhD_2017/courses/Sentiment-in-PD-Progression/parkinsons_submissions.csv")
comments_data = pd.read_csv("~/Dropbox/DZ_Work/UCL/RA_PhD_2017/courses/Sentiment-in-PD-Progression/parkinsons_comments.csv")

# %%
submissions_data = submissions_data[submissions_data["body"].notna()]
submissions_data = submissions_data[submissions_data["body"] != "[deleted]"]

submissions_data["body"] = [re.sub(r'[^\w\s]',' ', x) for x in submissions_data["body"]]
submissions_data["body"] = [re.sub(r'\n',' ', x) for x in submissions_data["body"]]
submissions_data["body"] = [re.sub(r'[0-9]',' ', x) for x in submissions_data["body"]]
submissions_data["body"] = [x.lower() for x in submissions_data["body"]]
submissions_data = submissions_data[[len(x) > 10 for x in submissions_data["body"]]]

# %%
from nltk.corpus import stopwords
sr = stopwords.words('english')

sr = sr + ["I", "My", "I'm", "like", "He", "know", "would", "get", "years", "really", "also", "The", "She", 
     "anyone", "I've", "It", "it", "We", "could", "he's", "someone", "https"]

clean_tokens = []
for comment in submissions_data["body"]:
    
    tokens = [t for t in comment.split()]
    
    for token in tokens:
        
        if token not in sr:
            
            if len(token) > 1:
            
                clean_tokens.append(token)

# %%
freq = nltk.FreqDist(clean_tokens)
plt.figure(figsize=(18, 15))
freq.plot(50, cumulative=False)

# %%
# Start with one review:
text = 

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
